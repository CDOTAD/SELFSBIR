# %%
import numpy as np
from PIL import Image

# %%
selected_img = Image.open('/data1/zzl/dataset/sketchydatabase_official_split/photo-test-all/butterfly/n02274259_8160.jpg')

# %%
selected_img = selected_img.resize((224, 224))

# %%
selected_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F46D18B77F0>

# %%
selected_sketch = Image.open('/data1/zzl/dataset/sketchydatabase_official_split/sketch-triplet-test-all/butterfly/n02274259_8160-2.png')

# %%
selected_sketch = selected_sketch.resize((224, 224))

# %%
selected_sketch
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F46D18AD5C0>

# %%
cls_cam = Image.open('/home/zzl/project/Grad-CAM.pytorch/resnet50_result/rnd_mix_edge/n02274259_8160-resnet50-cam.png')

# %%
cls_cam
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x7F46D0068D30>

# %%
cls_sketch_cam = Image.open('/home/zzl/project/Grad-CAM.pytorch/resnet50_result/rnd_mix_edge/n02274259_8160-2-resnet50-cam.png')

# %%
cls_sketch_cam
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x7F46C96F3C18>

# %%
selected_img_2 = Image.open('/data1/zzl/dataset/sketchydatabase_official_split/photo-test-all/airplane/n02691156_1512.jpg')

# %%
selected_sketch_2 = Image.open('/data1/zzl/dataset/sketchydatabase_official_split/sketch-triplet-test-all/airplane/n02691156_1512-1.png')

# %%
cls_cam_2 = Image.open('/home/zzl/project/Grad-CAM.pytorch/resnet50_result/rnd_mix_edge/n02691156_1512-resnet50-cam.png')

# %%
cls_sketch_cam_2 = Image.open('/home/zzl/project/Grad-CAM.pytorch/resnet50_result/rnd_mix_edge/n02691156_1512-1-resnet50-cam.png')

# %%
selected_img_2 =  selected_img_2.resize((224, 224))

# %%
selected_sketch_2 = selected_sketch_2.resize((224, 224))

# %%
selected_img = np.asarray(selected_img)

# %%
selected_sketch = np.asarray(selected_sketch)

# %%
selected_img_2 = np.asarray(selected_img_2)

# %%
selected_sketch_2 = np.asarray(selected_sketch_2)

# %%
cls_cam = np.asarray(cls_cam)

# %%
cls_sketch_cam = np.asarray(cls_sketch_cam)

# %%
cls_cam_2 = np.asarray(cls_cam_2)

# %%
cls_sketch_cam_2 = np.asarray(cls_sketch_cam_2)

# %%
result_image = np.concatenate([selected_img, selected_sketch, selected_img_2, selected_sketch_2], axis=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(result_image)

# %%
result_clm = np.concatenate([cls_cam, cls_sketch_cam, cls_cam_2, cls_sketch_cam_2], axis=1)

# %%
result_image = np.concatenate([result_image, result_clm], axis=0)

# %%
plt.imshow(result_image)

# %%
result_image = Image.fromarray(result_image)

# %%
result_image.save('cam_cls_result.png')

# %%
result_image.save('cam_mix_edge_result.png')
