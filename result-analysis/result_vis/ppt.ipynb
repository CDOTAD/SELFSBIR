# %%
import os

# %%
DATA_ROOT = '/home/zzl/ImageNet/ImageNet/ILSVRC2012/'

# %%
class_names = os.listdir(DATA_ROOT)

# %%
import random

# %%
cname = random.choice(class_names)

# %%
cname = 'n02108000.tar'

# %%
files = os.listdir(os.path.join(DATA_ROOT, cname))

# %%
from PIL import Image

# %%
f = random.choice(files)

# %%
img = Image.open(os.path.join(DATA_ROOT, cname, f))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=130x122 at 0x7F379C419438>

# %%
img.resize((255, 255))
# Out:
# <PIL.Image.Image image mode=RGB size=255x255 at 0x7F378C1C29B0>

# %%
import numpy as np

# %%
np.shape(img)
# Out:
# (500, 334, 3)

# %%
import cv2

# %%
def _canny_dec(img):
    img = np.asarray(img)
    img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img_np = cv2.GaussianBlur(img_gray, (5, 5), 0)
    canny = cv2.Canny(img_np, 50, 150)
    canny = 255 - canny
    img_edge = np.stack([canny, canny, canny], axis=2)
    img_edge = img_edge.astype(dtype=np.uint8)
    img_edge = Image.fromarray(img_edge, mode='RGB')
    return img_edge

# %%
_canny_dec(img)
# Out:
# <PIL.Image.Image image mode=RGB size=130x122 at 0x7F379C419C18>

# %%
edge = _canny_dec(img)

# %%
np.size(img)
# Out:
# (130, 122)

# %%
img = img.resize((255, 255))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=255x255 at 0x7F378C1C2390>

# %%
edge = _canny_dec(img)

# %%
img.save('./dog_intro.png')

# %%
edge.save('./dog_intro_edge.png')

# %%
img = np.asarray(img)

# %%
h, w = np.shape(img)[:2]

# %%
step_h = h //3
step_w = w // 3

# %%
for i in range(3):
    start_x = i * step_h
    end_x = start_x + step_h
    if i == 2:
        end_x = h
    for j in range(3):
        start_y = j * step_w
        end_y = start_y + step_w
        if j == 2:
            end_y = w
        
        img_crop = img[start_x: end_x, start_y: end_y, :].copy()
        img_crop = Image.fromarray(img_crop)
        img_crop.save('./img_intro_crop_{0}_{1}.png'.format(i, j))

# %%
edge = np.asarray(edge)

# %%
for i in range(3):
    start_x = i * step_h
    end_x = start_x + step_h
    if i == 2:
        end_x = h
    for j in range(3):
        start_y = j * step_w
        end_y = start_y + step_w
        if j == 2:
            end_y = w
        
        img_crop = edge[start_x: end_x, start_y: end_y, :].copy()
        img_crop = Image.fromarray(img_crop)
        img_crop.save('./edge_intro_crop_{0}_{1}.png'.format(i, j))

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=255x255 at 0x7F376CA5BC18>

# %%
Image.fromarray(edge)
# Out:
# <PIL.Image.Image image mode=RGB size=255x255 at 0x7F376C3696D8>

# %%
step_w
# Out:
# 85

# %%
mixed_img = np.zeros_like(img, dtype=np.uint8)

# %%
for i in range(3):
    start_x = i * step_h
    end_x = start_x + step_h
    if i == 2:
        end_x = h
    for j in range(3):
        start_y = j * step_w
        end_y = start_y + step_w
        if j == 2:
            end_y = w

        if random.random() >= 0.5:
            mixed_img[start_x:end_x, start_y:end_y, :] = img[start_x:end_x, start_y:end_y, :]
        else:
            mixed_img[start_x:end_x, start_y:end_y, :] = edge[start_x:end_x, start_y:end_y, :]

mixed_img = Image.fromarray(mixed_img, mode='RGB')

# %%
mixed_img
# Out:
# <PIL.Image.Image image mode=RGB size=255x255 at 0x7F376C3693C8>

# %%
mixed_img.save('./mixed_intor.png')

# %%
import os

# %%
DATA_ROOT = '/data1/zzl/dataset/sketchydatabase_official_split/sketch-triplet-train-all/'

# %%
classes = os.listdir(DATA_ROOT)

# %%
cname = 'dog'

# %%
files = os.listdir(os.path.join(DATA_ROOT, cname))

# %%
from PIL import Image

# %%
f = random.choice(files)

# %%
f
# Out:
# 'n02106662_2377-4.png'

# %%
f
# Out:
# 'n02106662_2377-4.png'

# %%
img = Image.open(os.path.join(DATA_ROOT, cname, f))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F376C390748>

# %%
img_save = Image.open('./dog_exp.png')

# %%
np.shape(img_save)
# Out:
# (255, 255, 3)

# %%
files = os.listdir('/data1/zzl/dataset/sketchydatabase_official_split/photo-train-all/dog/')

# %%
f = random.choice(files)

# %%
Image.open(os.path.join('/data1/zzl/dataset/sketchydatabase_official_split/photo-train-all/dog', f))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F3767A4E7F0>

# %%
f
# Out:
# 'n02109525_11444.jpg'
